# %%
import pandas as pd
import numpy as np

# %%
reviews = pd.read_csv('./archive/Reviews.csv')

# %%
reviews.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
reviews.isnull().sum()

# %%
reviews.UserId[reviews.Summary.isnull()]
# Out:
# 33958     A3TJPSWY2HE4BS
# 40548     A3TJPSWY2HE4BS
# 101106    A3TJPSWY2HE4BS
# 102979    A3TJPSWY2HE4BS
# 117515    A3TJPSWY2HE4BS
# 155712    A3TJPSWY2HE4BS
# 178290    A3TJPSWY2HE4BS
# 198474    A3TJPSWY2HE4BS
# 212691    A3TJPSWY2HE4BS
# 237565    A15AMT9T9A1309
# 293906    A3TJPSWY2HE4BS
# 299495    A3TJPSWY2HE4BS
# 300961    A3TJPSWY2HE4BS
# 333556    A3TJPSWY2HE4BS
# 352043    A3TJPSWY2HE4BS
# 357215    A3TJPSWY2HE4BS
# 357814    A3TJPSWY2HE4BS
# 360782    A3TJPSWY2HE4BS
# 379473    A3TJPSWY2HE4BS
# 380558    A3TJPSWY2HE4BS
# 381313    A3TJPSWY2HE4BS
# 386283    A3TJPSWY2HE4BS
# 392529    A22R17YPXEULEZ
# 484367    A3TJPSWY2HE4BS
# 486640    A3TJPSWY2HE4BS
# 503260    A3TJPSWY2HE4BS
# 530716    A3TJPSWY2HE4BS
# Name: UserId, dtype: object

# %%
reviews[reviews.ProfileName.isnull()]

# %%
reviews[reviews.UserId == 'A22R17YPXEULEZ']
# Out:
#             Id   ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 392529  392530  B001H9XOEW  A22R17YPXEULEZ    Liz Wong                     0
#
#         HelpfulnessDenominator  Score        Time Summary  \
# 392529                       0      3  1334534400     NaN
#
#                                                      Text
# 392529  I like the product and tried it before I pucha...

# %%
len(reviews[reviews.UserId == 'A3TJPSWY2HE4BS'])
# Out:
# 25

# %%
reviews[reviews.UserId == 'ABXLMWJIXXAIN']
# Out:
#             Id   ProductId         UserId                      ProfileName  \
# 2            3  B000LQOCH0  ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 320690  320691  B000CQ26E0  ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 468953  468954  B004DMGQKE  ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 2                          1                       1      4  1219017600
# 320690                     0                       0      4  1187740800
# 468953                     0                       0      5  1351209600
#
#                                    Summary  \
# 2                    "Delight" says it all
# 320690              Fast, Easy and organic
# 468953  Awesome service and great products
#
#                                                      Text
# 2       This is a confection that has been around a fe...
# 320690  For speed and wholesome goodness, Annie's can ...
# ...

# %%
reviews[reviews.UserId == 'A395BORC6FGVXV']
# Out:
#             Id   ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 3            4  B000UA0QIQ  A395BORC6FGVXV        Karl                     3
# 136303  136304  B002Y7526Y  A395BORC6FGVXV        Karl                     3
# 544172  544173  B000U9WZ54  A395BORC6FGVXV        Karl                     3
#
#         HelpfulnessDenominator  Score        Time         Summary  \
# 3                            3      2  1307923200  Cough Medicine
# 136303                       3      2  1307923200  Cough Medicine
# 544172                       3      2  1307923200  Cough Medicine
#
#                                                      Text
# 3       If you are looking for the secret ingredient i...
# 136303  If you are looking for the secret ingredient i...
# 544172  If you are looking for the secret ingredient i...

# %%
reviews.loc[:10]
# Out:
#     Id   ProductId          UserId                      ProfileName  \
# 0    1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1    2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2    3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3    4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4    5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5    6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6    7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7    8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8    9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9   10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
# 10  11  B0001PB9FE  A3HDKO7OW0QNK4                     Canadian Fan
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                      1                       1      5  1303862400
# ...

# %%
test = reviews.loc[:10]

# %%
df_2 = test.copy(deep=True)

# %%
df_2.drop(['Id', 'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator', 'Summary'], inplace = True, axis = 1)

# %%
from datetime import datetime

# %%
type(test.Time[0])
# Out:
# numpy.int64

# %%
ts = int(test.Time[0])
print(datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2011-04-27 00:00:00

# %%
#df_2.Time = df_2.Time.apply(lambda t: datetime.utcfromtimestamp(int(t)).strftime('%Y-%m-%d'))
df_2.Time = df_2.Time.apply(lambda t: datetime.utcfromtimestamp(int(t)).strftime('%Y'))

# %%
test.Time
# Out:
# 0     1303862400
# 1     1346976000
# 2     1219017600
# 3     1307923200
# 4     1350777600
# 5     1342051200
# 6     1340150400
# 7     1336003200
# 8     1322006400
# 9     1351209600
# 10    1107820800
# Name: Time, dtype: int64

# %%
df_2
# Out:
#      ProductId          UserId  Score  Time  \
# 0   B001E4KFG0  A3SGXH7AUHU8GW      5  2011
# 1   B00813GRG4  A1D87F6ZCVE5NK      1  2012
# 2   B000LQOCH0   ABXLMWJIXXAIN      4  2008
# 3   B000UA0QIQ  A395BORC6FGVXV      2  2011
# 4   B006K2ZZ7K  A1UQRSCLF8GW1T      5  2012
# 5   B006K2ZZ7K   ADT0SRK1MGOEU      4  2012
# 6   B006K2ZZ7K  A1SP2KVKFXXRU1      5  2012
# 7   B006K2ZZ7K  A3JRGQVEQN31IQ      5  2012
# 8   B000E7L2R4  A1MZYO9TZK0BBI      5  2011
# 9   B00171APVA  A21BT40VZCCYT4      5  2012
# 10  B0001PB9FE  A3HDKO7OW0QNK4      5  2005
#
#                                                  Text
# 0   I have bought several of the Vitality canned d...
# 1   Product arrived labeled as Jumbo Salted Peanut...
# 2   This is a confection that has been around a fe...
# 3   If you are looking for the secret ingredient i...
# 4   Great taffy at a great price.  There was a wid...
# 5   I got a wild hair for taffy and ordered this f...
# ...

# %%
df_2.to_csv('./archive/test_10_record.csv', index=False)

# %%
df_2.drop(['ProductId', 'UserId', 'Score'], inplace = True, axis = 1)

# %%
df_2
# Out:
#     Time                                               Text
# 0   2011  I have bought several of the Vitality canned d...
# 1   2012  Product arrived labeled as Jumbo Salted Peanut...
# 2   2008  This is a confection that has been around a fe...
# 3   2011  If you are looking for the secret ingredient i...
# 4   2012  Great taffy at a great price.  There was a wid...
# 5   2012  I got a wild hair for taffy and ordered this f...
# 6   2012  This saltwater taffy had great flavors and was...
# 7   2012  This taffy is so good.  It is very soft and ch...
# 8   2011  Right now I'm mostly just sprouting this so my...
# 9   2012  This is a very healthy dog food. Good for thei...
# 10  2005  I don't know if it's the cactus or the tequila...

# %%
df_2.to_csv(r'./archive/test_10_record.txt', header=None, index=None, sep='\t', mode='w')

# %%
pd.read_csv('./archive/test_10_record.csv')
# Out:
#      ProductId          UserId  Score        Time  \
# 0   B001E4KFG0  A3SGXH7AUHU8GW      5  2011-04-27
# 1   B00813GRG4  A1D87F6ZCVE5NK      1  2012-09-07
# 2   B000LQOCH0   ABXLMWJIXXAIN      4  2008-08-18
# 3   B000UA0QIQ  A395BORC6FGVXV      2  2011-06-13
# 4   B006K2ZZ7K  A1UQRSCLF8GW1T      5  2012-10-21
# 5   B006K2ZZ7K   ADT0SRK1MGOEU      4  2012-07-12
# 6   B006K2ZZ7K  A1SP2KVKFXXRU1      5  2012-06-20
# 7   B006K2ZZ7K  A3JRGQVEQN31IQ      5  2012-05-03
# 8   B000E7L2R4  A1MZYO9TZK0BBI      5  2011-11-23
# 9   B00171APVA  A21BT40VZCCYT4      5  2012-10-26
# 10  B0001PB9FE  A3HDKO7OW0QNK4      5  2005-02-08
#
#                                                  Text
# 0   I have bought several of the Vitality canned d...
# 1   Product arrived labeled as Jumbo Salted Peanut...
# 2   This is a confection that has been around a fe...
# 3   If you are looking for the secret ingredient i...
# 4   Great taffy at a great price.  There was a wid...
# ...

# %%
anno_parola = {}

# %%
words = {}

# %%
words['ciao'] = 1

# %%
words['sono'] = 2

# %%
words['a'] = 3

# %%
anno_parola[2011] = words

# %%
anno_parola[2010] = words

# %%
anno_parola
# Out:
# {2011: {'ciao': 1, 'sono': 2, 'a': 3, 'c': 0},
#  2010: {'ciao': 1, 'sono': 2, 'a': 3, 'c': 0}}

# %%
del anno_parola[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-85d31fc267be> in <module>
# ----> 1 del anno_parola[1]
#
# KeyError: 1

# %%
anno_parola[2011]['ciao']
# Out:
# 1

# %%
anno_parola[2011]['c'] = 0

# %%
anno_parola[2011].items()
# Out:
# dict_items([('ciao', 1), ('sono', 2), ('a', 3), ('c', 0)])

# %%
# Orinare dizionario di dizionario
sort_orders = sorted(anno_parola[2011].items(), key=lambda x: x[1], reverse = True)[:2]

# %%
sort_orders
# Out:
# [('a', 3), ('sono', 2)]

# %%
for year, words in anno_parola.items():
    print(words)
# Out:
# {'ciao': 1, 'sono': 2, 'a': 3, 'c': 0}
# {'ciao': 1, 'sono': 2, 'a': 3, 'c': 0}

# %%
ordered = sorted(words.items(), key=lambda x: x[1], reverse = True)

# %%
ordered_2 = sorted(words.values(), reverse = True)

# %%
ordered_2
# Out:
# [3, 2, 1, 0]

# %%
ordered
# Out:
# [('a', 3), ('sono', 2), ('ciao', 1), ('c', 0)]

# %%
for year, words in anno_parola.items():
    for i in sorted(words.items(), key=lambda x: x[1], reverse = True)[:4]:
        print(i[1])
        print("%i %s %s" % (year, i[0], i[1]))
# Out:
# 3
# 2011 a 3
# 2
# 2011 sono 2
# 1
# 2011 ciao 1
# 0
# 2011 c 0
# 3
# 2010 a 3
# 2
# 2010 sono 2
# 1
# 2010 ciao 1
# 0
# 2010 c 0

# %%
if 'ciao' in anno_parola[2011]:
    print("c")
# Out:
# c

# %%
year_word = {}

# %%
year_word[2012] = set()

# %%
year_word
# Out:
# {2012: {('Ciao', 1), ('sono', 2)}}

# %%
year_word[2012].add(('Ciao', 1))

# %%
year_word[2012].add(('sono', 2))

# %%
def remove_tags(text):
    return ''.join(xml.etree.ElementTree.fromstring(text).itertext())

# %%
import re
# as per recommendation from @freylis, compile once only
CLEANR = re.compile('<.*?>') 

def cleanhtml(raw_html): 
    return re.sub(CLEANR, ' ', raw_html)

# %%
import sys
import string
with open('./archive/test_10_record.txt') as f:
    contents = f.readlines()
    #print(contents)

    
i = 0

# read line from standard input
for line in contents:
    # removing leading/trailing whitespaces
    line = line.strip()
    # split the current line into words
    year, words = line.split("\t")
    
    # remove html tag inside text
    words = cleanhtml(words)
    # replace dot with withespace
    words = words.replace(".", " ")
    
    # remove punctuation
    words = words.translate(str.maketrans('', '', string.punctuation))
    words = re.sub(' +', ' ', words)
    words = words.strip()
    # splittare riga in words per il campo text
    words = words.split(" ")
    
    for word in words:
        # write in standard output the mapping word -> 1
        # in the form of tab-separated pairs
        with open('./archive/test_output.txt', 'a') as w:
            line = year + '\t' + word.lower() + '\t' + str(1) + '\n'
            w.writelines(line)
        print('%s\t%s\t%i' % (year, word.lower(), 1))
w.close()
f.close()
# Out:
# 2011	i	1
# 2011	have	1
# 2011	bought	1
# 2011	several	1
# 2011	of	1
# 2011	the	1
# 2011	vitality	1
# 2011	canned	1
# 2011	dog	1
# 2011	food	1
# 2011	products	1
# 2011	and	1
# 2011	have	1
# 2011	found	1
# 2011	them	1
# 2011	all	1
# 2011	to	1
# 2011	be	1
# 2011	of	1
# 2011	good	1
# 2011	quality	1
# 2011	the	1
# 2011	product	1
# 2011	looks	1
# 2011	more	1
# 2011	like	1
# 2011	a	1
# 2011	stew	1
# 2011	than	1
# 2011	a	1
# 2011	processed	1
# 2011	meat	1
# 2011	and	1
# 2011	it	1
# 2011	smells	1
# 2011	better	1
# 2011	my	1
# 2011	labrador	1
# 2011	is	1
# 2011	finicky	1
# 2011	and	1
# 2011	she	1
# 2011	appreciates	1
# 2011	this	1
# 2011	product	1
# 2011	better	1
# 2011	than	1
# 2011	most	1
# 2012	product	1
# 2012	arrived	1
# 2012	labeled	1
# 2012	as	1
# 2012	jumbo	1
# 2012	salted	1
# 2012	peanuts	1
# 2012	the	1
# 2012	peanuts	1
# 2012	were	1
# 2012	actually	1
# 2012	small	1
# 2012	sized	1
# 2012	unsalted	1
# 2012	not	1
# 2012	sure	1
# 2012	if	1
# 2012	this	1
# 2012	was	1
# 2012	an	1
# ...

# %%
testo = 'ciao...ciao.ciao.'
testo = testo.replace(".", " ")
print(testo)
testo = re.sub(' +', ' ', testo)
print(testo)
testo = testo.strip()
print(testo)
# Out:
# ciao   ciao ciao
# ciao ciao ciao
# ciao ciao ciao

# %%
firstString = "abc"
secondString = "def"
thirdString = "."
string = "abc"
print(string.maketrans('', thirdString))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-138397c2a433> in <module>
#       3 thirdString = "."
#       4 string = "abc"
# ----> 5 print(string.maketrans('', thirdString))
#
# ValueError: the first two maketrans arguments must have equal length

# %%
with open('./archive/test_output.txt') as f:
    contents = f.readlines()
year_words = {}

# input comes from STDIN
# note: this is the output from the mapper
for line in contents:

    # as usual, remove leading/trailing spaces
    line = line.strip()

    # parse the input elements
    year, current_word, current_count = line.split("\t")

    # convert count (currently a string) to int
    try:
        current_count = int(current_count)
        year = int(year)
    except ValueError:
        # count was not a number, in this case is just int
        continue

    # initialize word that were not seen befor with 0
    if year not in year_words:
        year_words[year] = {}
    
    if current_word not in year_words[year]:
        year_words[year][current_word] = 0
    
    year_words[year][current_word] += current_count

for year, words in year_words.items():
    print('%i' % year)
    for word in sorted(words.items(), key=lambda x: x[1], reverse = True)[:10]:
        print('\t%s\t%i' % (word[0], word[1]))
# Out:
# 2011
# 	i	6
# 	the	6
# 	and	5
# 	it	4
# 	have	3
# 	this	3
# 	of	2
# 	found	2
# 	to	2
# 	good	2
# 2012
# 	this	9
# 	a	9
# 	was	8
# 	taffy	8
# 	the	7
# 	very	6
# 	and	6
# 	is	5
# 	my	5
# 	it	5
# 2008
# 	and	6
# 	the	6
# 	is	5
# 	this	4
# 	a	4
# 	it	3
# 	with	3
# 	that	2
# 	into	2
# 	tiny	2
# 2005
# 	the	8
# 	of	8
# 	sauce	6
# 	a	6
# 	we	6
# 	it	5
# 	you	4
# 	hot	3
# 	were	3
# 	and	3
